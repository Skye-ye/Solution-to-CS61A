# %%
from datascience import *
import json
# %matplotlib inline

# %%
rs = [json.loads(s) for s in open('restaurants.json').readlines()]
rt = Table.from_records(rs)
rt.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>business_id</th> <th>categories</th> <th>city</th> <th>full_address</th> <th>latitude</th> <th>longitude</th> <th>name</th> <th>neighborhoods</th> <th>open</th> <th>photo_url</th> <th>price</th> <th>review_count</th> <th>schools</th> <th>stars</th> <th>state</th> <th>type</th> <th>url</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>gclB3ED6uk6viWlolSb_uA</td> <td>['Cafes', 'Restaurants'] </td> <td>Berkeley</td> <td>2400 Durant Ave
# Telegraph Ave
# Berkeley, CA 94701    </td> <td>37.8674 </td> <td>-122.26  </td> <td>Cafe 3      </td> <td>['Telegraph Ave', 'UC Campus Area']</td> <td>True</td> <td>http://s3-media1.ak.yelpcdn.com/bphoto/AaHq1UzXiT6zDBUYr ...</td> <td>1    </td> <td>9           </td> <td>['University of California at Berkeley']</td> <td>2    </td> <td>CA   </td> <td>business</td> <td>http://www.yelp.com/biz/cafe-3-berkeley      </td>
#         </tr>
# ...

# %%
Marker.map_table(rt.select("latitude", "longitude"))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
rt.group('stars').barh('stars')
